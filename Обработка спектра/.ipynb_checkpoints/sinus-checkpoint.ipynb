# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import numpy as np

# %%
points = list(range(1,15))
names = list(map(lambda x: 'point_{}'.format(x), points))

# %%
data = pd.read_excel('Mn_sw-15_ampl-210.xlsx', header=None, names = names)

# %%
weights = [np.sin(2* np.pi * rad) for i in range(14)]

# %%
arr_sin = list(range(0,13))
str_sin = []
full = list()
rad = 90/360

for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        str_sin = np.sum((np.sin((2* np.pi) * rad * (data.iloc[i][j] / 14))))
    full.append(str_sin)

# %%
str_sin
# Out:
# -0.900968867902418

# %%
len(full)
# Out:
# 999

# %%
plt.figure(figsize=(20,10))
plt.plot(range(999), full)
